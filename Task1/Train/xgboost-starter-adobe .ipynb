# %% [markdown]
# # Load Libraries

# %%
# LOAD LIBRARIES
import pandas as pd, numpy as np # CPU libraries
import cupy, cudf # GPU libraries
import matplotlib.pyplot as plt, gc, os

print('RAPIDS version',cudf.__version__)
# Out:
# RAPIDS version 21.10.01

# %%
# VERSION NAME FOR SAVED MODEL FILES
VER = 2

# TRAIN RANDOM SEED
SEED = 42

# FILL NAN VALUE
# NAN_VALUE = -127 # will fit in int8

# FOLDS PER MODEL
FOLDS = 5

# %%
def read_file(text_embedding_path, image_embedding_path, path = '', usecols = None):
    # LOAD DATAFRAME
    if usecols is not None: df = cudf.read_csv(path, columns=usecols)
    else: df = cudf.read_csv(path)
    text_embeddings = np.load(text_embedding_path)
    image_embeddings = np.load(image_embedding_path) 
    img_emb, text_emb = pd.DataFrame(image_embeddings), pd.DataFrame(text_embeddings)
    net_emb = pd.concat([img_emb, text_emb], axis = 1)
    net_emb.columns = range(len(net_emb.columns))
    net_emb = cudf.from_pandas(net_emb)
    concat_pd = cudf.concat([df, net_emb], axis = 1)
    features_to_drop = ['date', 'media', 'content_processed', 'Link','image_path', 'username', 'inferred company','Media Type']
    df = concat_pd.drop(columns = features_to_drop, inplace=False)
    print('shape of data:', df.shape)
    return df

print('Reading train data...')
TRAIN_PATH = '/kaggle/input/valid-dataset-adobe/valid_paths_data.csv'
IMG_EMB = '/kaggle/input/clipx32-batch-mpnetx8-batch/CLIP_Embeds.npy'
TEXT_EMB = '/kaggle/input/clipx32-batch-mpnetx8-batch/MPNET_Embeds.npy'
train = read_file(TEXT_EMB, IMG_EMB, path = TRAIN_PATH)
# Out:
# Reading train data...
# shape of data: (295502, 1798)

# %%
train['likes'] = cupy.log(train['likes'] + 1e-10)
train
# Out:
#             id         likes  hour  month  day of week  Year         0  \
# 0            1  1.000000e-10     0     12           12  2020 -0.246861
# 1            2  7.919356e+00    10      6           30  2018 -0.398804
# 2            3  4.043051e+00    19      9           29  2020 -0.091366
# 3            4  5.023881e+00    11     10            1  2020  0.536553
# 4            5  3.713572e+00    14     10           19  2018 -0.383302
# ...        ...           ...   ...    ...          ...   ...       ...
# 295497  299996 -2.302585e+01    16      9            7  2019  0.327817
# 295498  299997  3.828641e+00    11      2           23  2018  0.116493
# 295499  299998  5.564520e+00    20     11           11  2020 -0.302513
# 295500  299999  4.779123e+00    10     10           29  2019 -0.180378
# 295501  300000  6.570883e+00     1      8           26  2018  0.168857
#
#                1         2         3  ...      1782      1783      1784  \
# 0      -0.199877  0.156696  0.243754  ...  0.001865 -0.016018  0.072187
# 1      -0.299322 -0.262163  0.024715  ...  0.012844  0.045818  0.003134
# 2      -0.176465 -0.028901  0.074262  ...  0.025636  0.016661 -0.018063
# 3      -1.086032 -0.033425  0.178087  ... -0.027295 -0.022234  0.037092
# 4      -0.929385 -0.222161 -0.152471  ... -0.073161  0.031506  0.002639
# ...          ...       ...       ...  ...       ...       ...       ...
# 295497 -0.784044 -0.088061 -0.219255  ...  0.017004  0.002473  0.009592
# 295498 -0.262871  0.106194  0.574954  ... -0.019538  0.014360  0.017379
# 295499 -0.420806  0.207896 -0.177037  ...  0.006432  0.011452  0.040904
# 295500 -0.354582 -0.260322 -0.182210  ... -0.025157 -0.000011 -0.043119
# 295501  0.261406 -0.178011  0.238853  ...  0.027228  0.049255  0.000016
#
#             1785      1786      1787      1788      1789      1790      1791
# 0       0.005552  0.000850  0.042931 -0.003657  0.011115 -0.034018 -0.007277
# 1       0.006323  0.015455  0.047594 -0.005021  0.002013 -0.035605  0.008801
# 2       0.026398  0.003947  0.027403 -0.004428  0.035896 -0.074444 -0.020568
# 3      -0.018010 -0.008328 -0.060657  0.036714 -0.029977  0.001185 -0.008736
# 4       0.050263 -0.040711 -0.022616 -0.011846  0.014554  0.034135 -0.011808
# ...          ...       ...       ...       ...       ...       ...       ...
# 295497  0.011323 -0.039135 -0.038760  0.016228 -0.038038 -0.011835 -0.001271
# 295498 -0.019374 -0.011795 -0.027759  0.004184  0.019091  0.053744  0.003318
# 295499 -0.006894 -0.039816  0.009070 -0.002368  0.045965 -0.030693  0.000339
# 295500  0.020535 -0.016441  0.071141 -0.003668  0.053085  0.012343  0.007963
# 295501 -0.001839 -0.000861 -0.020891 -0.031027 -0.007696  0.036667 -0.009899
#
# [295502 rows x 1798 columns]

# %%
# FEATURES
FEATURES = train.columns[1:]
targets = train.columns[1]
print(f'There are {len(FEATURES)} features!')
print(f'This is {targets} Target!')
# Out:
# There are 1797 features!
# This is likes Target!

# %% [markdown]
# # Train XGB
# We will train using `DeviceQuantileDMatrix`. This has a very small GPU memory footprint.

# %%
# LOAD XGB LIBRARY
from sklearn.model_selection import KFold
import xgboost as xgb

# XGB MODEL PARAMETERS
xgb_parms = { 
    'max_depth': 3, 
    'learning_rate':0.01, 
    'subsample':0.8,
    'colsample_bytree':0.6,
    'tree_method':'gpu_hist',
    'predictor':'gpu_predictor',
    'random_state':SEED
}

# %%
# NEEDED WITH DeviceQuantileDMatrix BELOW
class IterLoadForDMatrix(xgb.core.DataIter):
    def __init__(self, df=None, features=None, target=None, batch_size=256*1024):
        """
        Custom iterator for loading data into a DeviceQuantileDMatrix in XGBoost.

        Args:
        - df (pd.DataFrame): DataFrame containing the data.
        - features (list): List of feature column names.
        - target (str): Name of the target column.
        - batch_size (int): Size of each batch (default is 256 * 1024).
        """
        self.features = features
        self.target = target
        self.df = df
        self.it = 0  # set iterator to 0
        self.batch_size = batch_size
        self.batches = int(np.ceil(len(df) / self.batch_size))
        super().__init__()

    def reset(self):
        '''Reset the iterator.'''
        self.it = 0

    def next(self, input_data):
        '''Yield next batch of data.'''
        if self.it == self.batches:
            return 0  # Return 0 when there's no more batch.

        a = self.it * self.batch_size
        b = min((self.it + 1) * self.batch_size, len(self.df))
        dt = cudf.DataFrame(self.df.iloc[a:b])
        
        # Provide the next batch of data to the input_data callback
        input_data(data=dt[self.features], label=dt[self.target])  #, weight=dt['weight'])
        
        self.it += 1
        return 1

# %%
if isinstance(train, pd.DataFrame):
    print("It's a pandas DataFrame.")
else:
    print("It's not a pandas DataFrame.")

# Check if it's a cuDF DataFrame
if isinstance(train, cudf.DataFrame):
    print("It's a cuDF DataFrame.")
else:
    print("It's not a cuDF DataFrame.")
# Out:
# It's not a pandas DataFrame.
# It's a cuDF DataFrame.

# %%
train.target = train.likes

# %%
import pandas
import cudf
from sklearn.metrics import mean_squared_error
from math import sqrt
importances = []
oof = []

# Convert cudf DataFrame to pandas DataFrame
train = train.to_pandas()  # free GPU memory

# Define the subsample ratio for training
TRAIN_SUBSAMPLE = 1.0

# Perform garbage collection to free up GPU memory
gc.collect()

# Initialize KFold with the specified number of folds
skf = KFold(n_splits=FOLDS, shuffle=True, random_state=SEED)

# Loop through each fold in the KFold cross-validation
for fold, (train_idx, valid_idx) in enumerate(skf.split(train, train.likes)):

    # TRAIN WITH SUBSAMPLE OF TRAIN FOLD DATA
    if TRAIN_SUBSAMPLE < 1.0:
        np.random.seed(SEED)
        train_idx = np.random.choice(train_idx, int(len(train_idx) * TRAIN_SUBSAMPLE), replace=False)
        np.random.seed(None)

    print('#' * 25)
    print('### Fold', fold + 1)
    print('### Train size', len(train_idx), 'Valid size', len(valid_idx))
    print(f'### Training with {int(TRAIN_SUBSAMPLE * 100)}% fold data...')
    print('#' * 25)

    # TRAIN, VALID, TEST FOR FOLD K
    Xy_train = IterLoadForDMatrix(train.loc[train_idx], FEATURES, 'likes')
    X_valid = train.loc[valid_idx, FEATURES]
    y_valid = train.loc[valid_idx, 'likes']

    # Create a DeviceQuantileDMatrix for training data
    dtrain = xgb.DeviceQuantileDMatrix(Xy_train, max_bin=256)
    
    # Create a DMatrix for validation data
    dvalid = xgb.DMatrix(data=X_valid, label=y_valid)

    # TRAIN MODEL FOLD K
    model = xgb.train(xgb_parms,
                      dtrain=dtrain,
# Out:
# #########################
# ### Fold 1
# ### Train size 236401 Valid size 59101
# ### Training with 100% fold data...
# #########################
# [0]	train-rmse:9.51717	valid-rmse:9.43799
# [100]	train-rmse:4.85754	valid-rmse:4.82223
# [200]	train-rmse:2.57161	valid-rmse:2.55757
# [300]	train-rmse:1.59334	valid-rmse:1.58748
# [400]	train-rmse:1.04133	valid-rmse:1.03997
# [500]	train-rmse:0.78613	valid-rmse:0.78681
# [600]	train-rmse:0.62458	valid-rmse:0.62656
# [700]	train-rmse:0.51216	valid-rmse:0.51497
# [800]	train-rmse:0.44851	valid-rmse:0.45183
# [900]	train-rmse:0.39707	valid-rmse:0.40053
# [1000]	train-rmse:0.36377	valid-rmse:0.36747
# [1100]	train-rmse:0.33849	valid-rmse:0.34240
# [1200]	train-rmse:0.31780	valid-rmse:0.32189
# [1300]	train-rmse:0.30216	valid-rmse:0.30622
# [1400]	train-rmse:0.28908	valid-rmse:0.29316
# [1500]	train-rmse:0.27833	valid-rmse:0.28235
# [1600]	train-rmse:0.26895	valid-rmse:0.27290
# [1700]	train-rmse:0.26085	valid-rmse:0.26471
# [1800]	train-rmse:0.25334	valid-rmse:0.25721
# [1900]	train-rmse:0.24691	valid-rmse:0.25073
# [2000]	train-rmse:0.24144	valid-rmse:0.24518
# [2100]	train-rmse:0.23616	valid-rmse:0.23983
# [2200]	train-rmse:0.23044	valid-rmse:0.23405
# [2300]	train-rmse:0.22624	valid-rmse:0.22980
# [2400]	train-rmse:0.22127	valid-rmse:0.22484
# [2500]	train-rmse:0.21755	valid-rmse:0.22109
# [2600]	train-rmse:0.21419	valid-rmse:0.21772
# [2700]	train-rmse:0.21106	valid-rmse:0.21457
# [2800]	train-rmse:0.20776	valid-rmse:0.21124
# [2900]	train-rmse:0.20449	valid-rmse:0.20795
# [3000]	train-rmse:0.20154	valid-rmse:0.20502
# [3100]	train-rmse:0.19909	valid-rmse:0.20259
# [3200]	train-rmse:0.19654	valid-rmse:0.20008
# [3300]	train-rmse:0.19432	valid-rmse:0.19787
# [3400]	train-rmse:0.19205	valid-rmse:0.19557
# [3500]	train-rmse:0.18959	valid-rmse:0.19313
# [3600]	train-rmse:0.18765	valid-rmse:0.19119
# [3700]	train-rmse:0.18538	valid-rmse:0.18895
# [3800]	train-rmse:0.18336	valid-rmse:0.18696
# [3900]	train-rmse:0.18153	valid-rmse:0.18516
# [4000]	train-rmse:0.17996	valid-rmse:0.18364
# [4100]	train-rmse:0.17846	valid-rmse:0.18217
# [4200]	train-rmse:0.17712	valid-rmse:0.18088
# [4300]	train-rmse:0.17551	valid-rmse:0.17928
# [4400]	train-rmse:0.17409	valid-rmse:0.17790
# [4500]	train-rmse:0.17258	valid-rmse:0.17640
# [4600]	train-rmse:0.17126	valid-rmse:0.17510
# [4700]	train-rmse:0.17016	valid-rmse:0.17402
# [4900]	train-rmse:0.16802	valid-rmse:0.17193
# [4998]	train-rmse:0.16691	valid-rmse:0.17084
# RMSE = 0.17083785671315663
#
# #########################
# ### Fold 2
# ### Train size 236401 Valid size 59101
# ### Training with 100% fold data...
# #########################
# [0]	train-rmse:9.49454	valid-rmse:9.52873
# [100]	train-rmse:4.84456	valid-rmse:4.87130
# [200]	train-rmse:2.56633	valid-rmse:2.58485
# [300]	train-rmse:1.59166	valid-rmse:1.60532
# [400]	train-rmse:1.04281	valid-rmse:1.05139
# [500]	train-rmse:0.78684	valid-rmse:0.79251
# [600]	train-rmse:0.62609	valid-rmse:0.62944
# [700]	train-rmse:0.51241	valid-rmse:0.51484
# [800]	train-rmse:0.45019	valid-rmse:0.45239
# [900]	train-rmse:0.40022	valid-rmse:0.40211
# [1000]	train-rmse:0.36671	valid-rmse:0.36863
# [1100]	train-rmse:0.34138	valid-rmse:0.34330
# [1200]	train-rmse:0.31986	valid-rmse:0.32173
# [1300]	train-rmse:0.30420	valid-rmse:0.30616
# [1400]	train-rmse:0.29124	valid-rmse:0.29337
# [1500]	train-rmse:0.28052	valid-rmse:0.28279
# [1600]	train-rmse:0.27105	valid-rmse:0.27346
# [1700]	train-rmse:0.26278	valid-rmse:0.26534
# [1800]	train-rmse:0.25538	valid-rmse:0.25802
# [1900]	train-rmse:0.24862	valid-rmse:0.25139
# [2000]	train-rmse:0.24251	valid-rmse:0.24544
# [2100]	train-rmse:0.23771	valid-rmse:0.24076
# [2200]	train-rmse:0.23262	valid-rmse:0.23577
# [2300]	train-rmse:0.22840	valid-rmse:0.23168
# [2400]	train-rmse:0.22365	valid-rmse:0.22702
# [2500]	train-rmse:0.21985	valid-rmse:0.22332
# [2600]	train-rmse:0.21633	valid-rmse:0.21990
# [2700]	train-rmse:0.21264	valid-rmse:0.21633
# [2800]	train-rmse:0.20985	valid-rmse:0.21365
# [2900]	train-rmse:0.20661	valid-rmse:0.21049
# [3000]	train-rmse:0.20339	valid-rmse:0.20734
# [3100]	train-rmse:0.20094	valid-rmse:0.20495
# [3200]	train-rmse:0.19828	valid-rmse:0.20235
# [3300]	train-rmse:0.19612	valid-rmse:0.20021
# [3400]	train-rmse:0.19380	valid-rmse:0.19793
# [3500]	train-rmse:0.19138	valid-rmse:0.19555
# [3600]	train-rmse:0.18935	valid-rmse:0.19357
# [3700]	train-rmse:0.18723	valid-rmse:0.19148
# [3800]	train-rmse:0.18538	valid-rmse:0.18969
# [3900]	train-rmse:0.18369	valid-rmse:0.18804
# [4000]	train-rmse:0.18203	valid-rmse:0.18644
# [4100]	train-rmse:0.18047	valid-rmse:0.18492
# [4200]	train-rmse:0.17907	valid-rmse:0.18358
# [4300]	train-rmse:0.17771	valid-rmse:0.18227
# [4400]	train-rmse:0.17633	valid-rmse:0.18093
# [4500]	train-rmse:0.17486	valid-rmse:0.17949
# [4600]	train-rmse:0.17366	valid-rmse:0.17833
# [4700]	train-rmse:0.17258	valid-rmse:0.17733
# [4800]	train-rmse:0.17138	valid-rmse:0.17618
# [4900]	train-rmse:0.17038	valid-rmse:0.17523
# [4998]	train-rmse:0.16922	valid-rmse:0.17410
# RMSE = 0.1741001486352443
#
# #########################
# ### Fold 3
# ### Train size 236402 Valid size 59100
# ### Training with 100% fold data...
# #########################
# [0]	train-rmse:9.50642	valid-rmse:9.48120
# [100]	train-rmse:4.85282	valid-rmse:4.84323
# [200]	train-rmse:2.57075	valid-rmse:2.56918
# [300]	train-rmse:1.59295	valid-rmse:1.59660
# [400]	train-rmse:1.04106	valid-rmse:1.04692
# [500]	train-rmse:0.78674	valid-rmse:0.79371
# [600]	train-rmse:0.62665	valid-rmse:0.63407
# [700]	train-rmse:0.51489	valid-rmse:0.52246
# [800]	train-rmse:0.45175	valid-rmse:0.45915
# [900]	train-rmse:0.40200	valid-rmse:0.40911
# [1000]	train-rmse:0.36844	valid-rmse:0.37529
# [1100]	train-rmse:0.34253	valid-rmse:0.34915
# [1200]	train-rmse:0.32096	valid-rmse:0.32750
# [1300]	train-rmse:0.30460	valid-rmse:0.31119
# [1400]	train-rmse:0.29145	valid-rmse:0.29796
# [1500]	train-rmse:0.28056	valid-rmse:0.28697
# [1600]	train-rmse:0.27058	valid-rmse:0.27691
# [1700]	train-rmse:0.26204	valid-rmse:0.26831
# [1800]	train-rmse:0.25406	valid-rmse:0.26033
# [1900]	train-rmse:0.24768	valid-rmse:0.25391
# [2000]	train-rmse:0.24211	valid-rmse:0.24829
# [2100]	train-rmse:0.23716	valid-rmse:0.24333
# [2200]	train-rmse:0.23163	valid-rmse:0.23778
# [2300]	train-rmse:0.22709	valid-rmse:0.23324
# [2400]	train-rmse:0.22195	valid-rmse:0.22810
# [2500]	train-rmse:0.21805	valid-rmse:0.22420
# [2600]	train-rmse:0.21465	valid-rmse:0.22078
# [2700]	train-rmse:0.21177	valid-rmse:0.21790
# [2800]	train-rmse:0.20898	valid-rmse:0.21510
# [2900]	train-rmse:0.20628	valid-rmse:0.21241
# [3000]	train-rmse:0.20300	valid-rmse:0.20915
# [3100]	train-rmse:0.20052	valid-rmse:0.20670
# [3200]	train-rmse:0.19818	valid-rmse:0.20439
# [3300]	train-rmse:0.19610	valid-rmse:0.20234
# [3400]	train-rmse:0.19379	valid-rmse:0.20005
# [3500]	train-rmse:0.19130	valid-rmse:0.19757
# [3600]	train-rmse:0.18926	valid-rmse:0.19553
# [3700]	train-rmse:0.18722	valid-rmse:0.19350
# [3800]	train-rmse:0.18523	valid-rmse:0.19152
# [3900]	train-rmse:0.18370	valid-rmse:0.19001
# [4000]	train-rmse:0.18205	valid-rmse:0.18839
# [4100]	train-rmse:0.18058	valid-rmse:0.18692
# [4200]	train-rmse:0.17924	valid-rmse:0.18560
# [4300]	train-rmse:0.17806	valid-rmse:0.18445
# [4400]	train-rmse:0.17661	valid-rmse:0.18301
# [4500]	train-rmse:0.17511	valid-rmse:0.18150
# [4600]	train-rmse:0.17388	valid-rmse:0.18029
# [4700]	train-rmse:0.17277	valid-rmse:0.17922
# [4800]	train-rmse:0.17166	valid-rmse:0.17812
# [4900]	train-rmse:0.17062	valid-rmse:0.17709
# [4998]	train-rmse:0.16934	valid-rmse:0.17584
# RMSE = 0.17583516687321227
#
# #########################
# ### Fold 4
# ### Train size 236402 Valid size 59100
# ### Training with 100% fold data...
# #########################
# [0]	train-rmse:9.50510	valid-rmse:9.48656
# [100]	train-rmse:4.85199	valid-rmse:4.84404
# [300]	train-rmse:1.59363	valid-rmse:1.59506
# [400]	train-rmse:1.04039	valid-rmse:1.04408
# [500]	train-rmse:0.78596	valid-rmse:0.79042
# [600]	train-rmse:0.62537	valid-rmse:0.62942
# [700]	train-rmse:0.51043	valid-rmse:0.51414
# [800]	train-rmse:0.44803	valid-rmse:0.45144
# [900]	train-rmse:0.39842	valid-rmse:0.40153
# [1000]	train-rmse:0.36364	valid-rmse:0.36665
# [1100]	train-rmse:0.33768	valid-rmse:0.34063
# [1200]	train-rmse:0.31725	valid-rmse:0.32018
# [1300]	train-rmse:0.30181	valid-rmse:0.30480
# [1400]	train-rmse:0.28896	valid-rmse:0.29197
# [1500]	train-rmse:0.27847	valid-rmse:0.28150
# [1600]	train-rmse:0.26920	valid-rmse:0.27225
# [1700]	train-rmse:0.26036	valid-rmse:0.26338
# [1800]	train-rmse:0.25302	valid-rmse:0.25616
# [1900]	train-rmse:0.24603	valid-rmse:0.24928
# [2000]	train-rmse:0.24080	valid-rmse:0.24412
# [2100]	train-rmse:0.23588	valid-rmse:0.23934
# [2200]	train-rmse:0.23052	valid-rmse:0.23406
# [2300]	train-rmse:0.22608	valid-rmse:0.22970
# [2400]	train-rmse:0.22124	valid-rmse:0.22496
# [2500]	train-rmse:0.21763	valid-rmse:0.22140
# [2600]	train-rmse:0.21385	valid-rmse:0.21769
# [2700]	train-rmse:0.21055	valid-rmse:0.21443
# [2800]	train-rmse:0.20768	valid-rmse:0.21163
# [2900]	train-rmse:0.20473	valid-rmse:0.20873
# [3000]	train-rmse:0.20184	valid-rmse:0.20591
# [3100]	train-rmse:0.19922	valid-rmse:0.20336
# [3200]	train-rmse:0.19707	valid-rmse:0.20125
# [3300]	train-rmse:0.19484	valid-rmse:0.19906
# [3400]	train-rmse:0.19233	valid-rmse:0.19658
# [3500]	train-rmse:0.19006	valid-rmse:0.19436
# [3600]	train-rmse:0.18811	valid-rmse:0.19245
# [3700]	train-rmse:0.18610	valid-rmse:0.19049
# [3800]	train-rmse:0.18424	valid-rmse:0.18866
# [3900]	train-rmse:0.18261	valid-rmse:0.18707
# [4000]	train-rmse:0.18104	valid-rmse:0.18557
# [4100]	train-rmse:0.17958	valid-rmse:0.18415
# [4200]	train-rmse:0.17824	valid-rmse:0.18286
# [4300]	train-rmse:0.17669	valid-rmse:0.18134
# [4400]	train-rmse:0.17538	valid-rmse:0.18009
# [4500]	train-rmse:0.17397	valid-rmse:0.17873
# [4600]	train-rmse:0.17276	valid-rmse:0.17756
# [4700]	train-rmse:0.17158	valid-rmse:0.17641
# [4800]	train-rmse:0.17056	valid-rmse:0.17545
# [4900]	train-rmse:0.16942	valid-rmse:0.17433
# [4998]	train-rmse:0.16813	valid-rmse:0.17306
# RMSE = 0.17305845897145472
#
# #########################
# ### Fold 5
# ### Train size 236402 Valid size 59100
# ### Training with 100% fold data...
# #########################
# [0]	train-rmse:9.48367	valid-rmse:9.57192
# [100]	train-rmse:4.84072	valid-rmse:4.88354
# [200]	train-rmse:2.56527	valid-rmse:2.58671
# [300]	train-rmse:1.59035	valid-rmse:1.60413
# [400]	train-rmse:1.04018	valid-rmse:1.05038
# [500]	train-rmse:0.78573	valid-rmse:0.79433
# [600]	train-rmse:0.62569	valid-rmse:0.63315
# [700]	train-rmse:0.51284	valid-rmse:0.52003
# [800]	train-rmse:0.45074	valid-rmse:0.45773
# [900]	train-rmse:0.40101	valid-rmse:0.40811
# [1100]	train-rmse:0.34081	valid-rmse:0.34754
# [1200]	train-rmse:0.31930	valid-rmse:0.32588
# [1300]	train-rmse:0.30354	valid-rmse:0.31000
# [1400]	train-rmse:0.29081	valid-rmse:0.29719
# [1500]	train-rmse:0.27956	valid-rmse:0.28592
# [1600]	train-rmse:0.26952	valid-rmse:0.27586
# [1700]	train-rmse:0.26101	valid-rmse:0.26734
# [1800]	train-rmse:0.25371	valid-rmse:0.26007
# [1900]	train-rmse:0.24732	valid-rmse:0.25372
# [2000]	train-rmse:0.24182	valid-rmse:0.24819
# [2100]	train-rmse:0.23650	valid-rmse:0.24288
# [2200]	train-rmse:0.23043	valid-rmse:0.23674
# [2300]	train-rmse:0.22619	valid-rmse:0.23249
# [2400]	train-rmse:0.22166	valid-rmse:0.22795
# [2500]	train-rmse:0.21834	valid-rmse:0.22465
# [2600]	train-rmse:0.21493	valid-rmse:0.22124
# [2700]	train-rmse:0.21161	valid-rmse:0.21793
# [2800]	train-rmse:0.20865	valid-rmse:0.21497
# [2900]	train-rmse:0.20581	valid-rmse:0.21217
# [3000]	train-rmse:0.20257	valid-rmse:0.20893
# [3100]	train-rmse:0.19973	valid-rmse:0.20612
# [3200]	train-rmse:0.19770	valid-rmse:0.20413
# [3300]	train-rmse:0.19518	valid-rmse:0.20165
# [3400]	train-rmse:0.19285	valid-rmse:0.19935
# [3500]	train-rmse:0.19060	valid-rmse:0.19712
# [3600]	train-rmse:0.18842	valid-rmse:0.19498
# [3700]	train-rmse:0.18623	valid-rmse:0.19282
# [3800]	train-rmse:0.18434	valid-rmse:0.19096
# [3900]	train-rmse:0.18261	valid-rmse:0.18927
# [4000]	train-rmse:0.18091	valid-rmse:0.18761
# [4100]	train-rmse:0.17932	valid-rmse:0.18604
# [4200]	train-rmse:0.17782	valid-rmse:0.18456
# [4300]	train-rmse:0.17650	valid-rmse:0.18329
# [4400]	train-rmse:0.17476	valid-rmse:0.18153
# [4500]	train-rmse:0.17335	valid-rmse:0.18012
# [4600]	train-rmse:0.17212	valid-rmse:0.17892
# [4700]	train-rmse:0.17081	valid-rmse:0.17765
# [4800]	train-rmse:0.16974	valid-rmse:0.17661
# [4900]	train-rmse:0.16878	valid-rmse:0.17569
# [4998]	train-rmse:0.16758	valid-rmse:0.17453
# RMSE = 0.1745335208175041
#
# #########################

# %%
train.id
# Out:
# 0              1
# 1              2
# 2              3
# 3              4
# 4              5
#            ...
# 295497    299996
# 295498    299997
# 295499    299998
# 295500    299999
# 295501    300000
# Name: id, Length: 295502, dtype: int64

# %%
# CLEAN RAM
del train
_ = gc.collect()
